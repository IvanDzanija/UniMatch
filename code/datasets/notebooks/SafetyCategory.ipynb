# %%
import pandas as pd
import numpy as np
import os


dataset_path = os.path.join('..', 'LLM_generated', 'pricesLLM.csv')
df = pd.read_csv(dataset_path)

# %%
df.head()
# columns_of_interest = [
#     'ranking', 'tuition', 'percOfIntStud', 'acceptanceRate', 
#     'livingCost', 'rentCost', 'groceriesCost', 
#     'recreationCost', 'healthcareCost', 'transportCost'
# ]

# max_values = df[columns_of_interest].max()

# print("Maximum values of selected columns:")
# print(max_values)

# min_values = df[columns_of_interest].min()

# print("Minimum values of selected columns:")
# print(min_values)
# Out:
#      Country                  University CollegeRank  Tuition  PercOfIntStud  \
# 0    ALBANIA        University of Tirana       1001+     1500              5
# 1    ALGERIA       University of Algiers       1001+      800              2
# 2  ARGENTINA  University of Buenos Aires         131        0              8
# 3    ARMENIA    Yerevan State University       1001+     2000              6
# 4  AUSTRALIA     University of Melbourne          32    32000             44
#
#    AcceptanceRate  SafetyIndex  LivingCost  RentCost  GroceriesCost  ...  \
# 0              60           70         600       250            150  ...
# 1              50           65         550       200            120  ...
# 2              65           70         600       250            150  ...
# 3              40           70         600       250            120  ...
# 4              70           85        2000      1200            400  ...
#
#    Biology  Law  Medicine Mathematics  Art  Physics  Latitude  Longitude  \
# 0        1    1         1           0    1        1   41.3275    19.8189
# 1        1    1         1           1    1        1   36.7529     3.0420
# 2        1    1         1           1    1        1  -34.5997   -58.3721
# 3        1    1         1           1    1        1   40.1872    44.5152
# 4        1    1         1           1    1        1  -37.7962   144.9614
#
#    Ranking            region
# 0   2001.0            Europe
# 1   2001.0            Africa
# 2   2001.0  Southern America
# 3   1902.0              Asia
# 4     37.0           Oceania
#
# [5 rows x 28 columns]

# %%
def classify_safety(safety_value):
    thresholds = {
        'low-safety': (0, 40),
        'low-medium-safety': (40, 55),
        'medium-safety': (55, 65),
        'medium-high safety': (65, 75),
        'high-safety': (75, 100)
    }
    
    for category, (min_val, max_val) in thresholds.items():
        if min_val <= safety_value < max_val:
            return category
    return 'Unknown'

df['SafetyCategory'] = df['SafetyIndex'].apply(classify_safety)

# print(df[['safetyIndex', 'safetyCategory']].head())

df.to_csv('pricesLLMGlobal.csv', index=False)
